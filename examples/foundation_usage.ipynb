# %% [markdown]
# ##  Example: Extract U-Trans Latent Representation and Decoder Features
#
# This example shows how to:
#
# - Load the full **U-Trans foundation model** (UNET + transformer backbone)
# - Extract the latent token representation **(75, 80)**
# - Generate the decoder features **(6000, 1)** that are ready to concatenate with downstream tasks Example: Extract U-Trans Latent Representation and Decoder Features
#
# This example shows how to:
#
# - Load the full **U-Trans foundation model** (UNET + transformer backbone)
# - Extract the latent token representation **(75, 80)**
# - Generate the decoder features **(6000, 1)** that are ready to concatenate with downstream tasks

# %%
"""
U-Trans Foundation Model Usage Example
=======================================

This script:

1) Loads pretrained U-Trans foundation weights.
2) Extracts the latent transformer representation.
3) Builds the decoder feature stream (6000, 1) ready for concatenation
   with downstream tasks.

Expected input shape:
    (B, 6000, 3)

Where:
    B = batch size
    6000 = waveform length
    3 = three-component waveform
"""

import os
import sys
import numpy as np

# ---------------------------------------------------------
# If notebook is inside examples/, add repo root to path
# ---------------------------------------------------------
sys.path.insert(0, os.path.abspath(".."))

from utrans.foundation import get_latent_model, get_decoder_model


# ---------------------------------------------------------
# Path to pretrained foundation weights
# ---------------------------------------------------------
UNET_WEIGHTS = "../weights/UTrans_Foundation.h5"


# ---------------------------------------------------------
# Model that outputs transformer latent tokens
# Expected output shape: (B, 75, 80)
# ---------------------------------------------------------
latent_model = get_latent_model(UNET_WEIGHTS)


# ---------------------------------------------------------
# Model that outputs decoder features
# ready_to_concatenate_model -> Keras model
# Featuear_Ready_to_Concatenate -> feature tensor shape
# Expected decoder feature shape: (B, 6000, 1)
# ---------------------------------------------------------
ready_to_concatenate_model, Featuear_Ready_to_Concatenate = get_decoder_model(UNET_WEIGHTS)


# ---------------------------------------------------------
# Display architecture and output shape
# ---------------------------------------------------------
ready_to_concatenate_model.summary()
Featuear_Ready_to_Concatenate.shape
# Out:
# 2026-02-26 00:50:27.340993: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-02-26 00:50:30.257050: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31615 MB memory:  -> device: 0, name: Quadro RTX 8000, pci bus id: 0000:18:00.0, compute capability: 7.5
# 2026-02-26 00:50:30.258429: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 17760 MB memory:  -> device: 1, name: Quadro RTX 8000, pci bus id: 0000:3b:00.0, compute capability: 7.5
# 2026-02-26 00:50:30.259476: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 5416 MB memory:  -> device: 2, name: Quadro RTX 8000, pci bus id: 0000:86:00.0, compute capability: 7.5
# 2026-02-26 00:50:30.261194: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 47225 MB memory:  -> device: 3, name: Quadro RTX 8000, pci bus id: 0000:af:00.0, compute capability: 7.5
# Model: "UTrans_decoder_features"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 6000, 3)]    0           []
#
#  conv1d_29 (Conv1D)             (None, 6000, 5)      50          ['input[0][0]']
#
#  conv1d_30 (Conv1D)             (None, 6000, 5)      80          ['conv1d_29[0][0]']
#
#  max_pooling1d_5 (MaxPooling1D)  (None, 3000, 5)     0           ['conv1d_30[0][0]']
#
#  conv1d_31 (Conv1D)             (None, 3000, 10)     160         ['max_pooling1d_5[0][0]']
#
#  conv1d_32 (Conv1D)             (None, 3000, 10)     310         ['conv1d_31[0][0]']
#
#  max_pooling1d_6 (MaxPooling1D)  (None, 1500, 10)    0           ['conv1d_32[0][0]']
#
#  conv1d_33 (Conv1D)             (None, 1500, 20)     620         ['max_pooling1d_6[0][0]']
#
#  conv1d_34 (Conv1D)             (None, 1500, 20)     1220        ['conv1d_33[0][0]']
#
#  max_pooling1d_7 (MaxPooling1D)  (None, 750, 20)     0           ['conv1d_34[0][0]']
#
#  conv1d_35 (Conv1D)             (None, 750, 40)      2440        ['max_pooling1d_7[0][0]']
#
#  conv1d_36 (Conv1D)             (None, 750, 40)      4840        ['conv1d_35[0][0]']
#
#  max_pooling1d_8 (MaxPooling1D)  (None, 375, 40)     0           ['conv1d_36[0][0]']
#
#  conv1d_37 (Conv1D)             (None, 375, 80)      9680        ['max_pooling1d_8[0][0]']
#
#  conv1d_38 (Conv1D)             (None, 375, 80)      19280       ['conv1d_37[0][0]']
#
#  max_pooling1d_9 (MaxPooling1D)  (None, 75, 80)      0           ['conv1d_38[0][0]']
#
#  conv1d_39 (Conv1D)             (None, 75, 80)       19280       ['max_pooling1d_9[0][0]']
#
#  conv1d_40 (Conv1D)             (None, 75, 80)       19280       ['conv1d_39[0][0]']
#
#  cct_tokenizer1_1 (CCTTokenizer  (None, 75, 80)      19200       ['conv1d_40[0][0]']
#  1)
#
#  layer_normalization_9 (LayerNo  (None, 75, 80)      160         ['cct_tokenizer1_1[0][0]']
#  rmalization)
#
#  multi_head_attention_4 (MultiH  (None, 75, 80)      103440      ['layer_normalization_9[0][0]',
#  eadAttention)                                                    'layer_normalization_9[0][0]']
#
#  stochastic_depth_8 (Stochastic  (None, 75, 80)      0           ['multi_head_attention_4[0][0]']
#  Depth)
#
#  add_8 (Add)                    (None, 75, 80)       0           ['stochastic_depth_8[0][0]',
#                                                                   'cct_tokenizer1_1[0][0]']
#
#  layer_normalization_10 (LayerN  (None, 75, 80)      160         ['add_8[0][0]']
#  ormalization)
#
#  dense_8 (Dense)                (None, 75, 80)       6480        ['layer_normalization_10[0][0]']
#
#  dropout_8 (Dropout)            (None, 75, 80)       0           ['dense_8[0][0]']
#
#  dense_9 (Dense)                (None, 75, 80)       6480        ['dropout_8[0][0]']
#
#  dropout_9 (Dropout)            (None, 75, 80)       0           ['dense_9[0][0]']
#
#  stochastic_depth_9 (Stochastic  (None, 75, 80)      0           ['dropout_9[0][0]']
#  Depth)
#
#  add_9 (Add)                    (None, 75, 80)       0           ['stochastic_depth_9[0][0]',
#                                                                   'add_8[0][0]']
#
#  layer_normalization_11 (LayerN  (None, 75, 80)      160         ['add_9[0][0]']
#  ormalization)
#
#  multi_head_attention_5 (MultiH  (None, 75, 80)      103440      ['layer_normalization_11[0][0]',
#  eadAttention)                                                    'layer_normalization_11[0][0]']
#
#  stochastic_depth_10 (Stochasti  (None, 75, 80)      0           ['multi_head_attention_5[0][0]']
#  cDepth)
#
#  add_10 (Add)                   (None, 75, 80)       0           ['stochastic_depth_10[0][0]',
#                                                                   'add_9[0][0]']
#  layer_normalization_12 (LayerN  (None, 75, 80)      160         ['add_10[0][0]']
#  ormalization)
#
#  dense_10 (Dense)               (None, 75, 80)       6480        ['layer_normalization_12[0][0]']
#
#  dropout_10 (Dropout)           (None, 75, 80)       0           ['dense_10[0][0]']
#
#  dense_11 (Dense)               (None, 75, 80)       6480        ['dropout_10[0][0]']
#
#  dropout_11 (Dropout)           (None, 75, 80)       0           ['dense_11[0][0]']
#
#  stochastic_depth_11 (Stochasti  (None, 75, 80)      0           ['dropout_11[0][0]']
#  cDepth)
#
#  add_11 (Add)                   (None, 75, 80)       0           ['stochastic_depth_11[0][0]',
#                                                                   'add_10[0][0]']
#
#  layer_normalization_13 (LayerN  (None, 75, 80)      160         ['add_11[0][0]']
#  ormalization)
#
#  multi_head_attention_6 (MultiH  (None, 75, 80)      103440      ['layer_normalization_13[0][0]',
#  eadAttention)                                                    'layer_normalization_13[0][0]']
#
#  stochastic_depth_12 (Stochasti  (None, 75, 80)      0           ['multi_head_attention_6[0][0]']
#  cDepth)
#
#  add_12 (Add)                   (None, 75, 80)       0           ['stochastic_depth_12[0][0]',
#                                                                   'add_11[0][0]']
#
#  layer_normalization_14 (LayerN  (None, 75, 80)      160         ['add_12[0][0]']
#  ormalization)
#
#  dense_12 (Dense)               (None, 75, 80)       6480        ['layer_normalization_14[0][0]']
#
#  dropout_12 (Dropout)           (None, 75, 80)       0           ['dense_12[0][0]']
#
#  dense_13 (Dense)               (None, 75, 80)       6480        ['dropout_12[0][0]']
#
#  dropout_13 (Dropout)           (None, 75, 80)       0           ['dense_13[0][0]']
#
#  stochastic_depth_13 (Stochasti  (None, 75, 80)      0           ['dropout_13[0][0]']
#  cDepth)
#
#  add_13 (Add)                   (None, 75, 80)       0           ['stochastic_depth_13[0][0]',
#                                                                   'add_12[0][0]']
#
#  layer_normalization_15 (LayerN  (None, 75, 80)      160         ['add_13[0][0]']
#  ormalization)
#
#  multi_head_attention_7 (MultiH  (None, 75, 80)      103440      ['layer_normalization_15[0][0]',
#  eadAttention)                                                    'layer_normalization_15[0][0]']
#
#  stochastic_depth_14 (Stochasti  (None, 75, 80)      0           ['multi_head_attention_7[0][0]']
#  cDepth)
#
#  add_14 (Add)                   (None, 75, 80)       0           ['stochastic_depth_14[0][0]',
#                                                                   'add_13[0][0]']
#
#  layer_normalization_16 (LayerN  (None, 75, 80)      160         ['add_14[0][0]']
#  ormalization)
#
#  dense_14 (Dense)               (None, 75, 80)       6480        ['layer_normalization_16[0][0]']
#
#  dropout_14 (Dropout)           (None, 75, 80)       0           ['dense_14[0][0]']
#
#  dense_15 (Dense)               (None, 75, 80)       6480        ['dropout_14[0][0]']
#
#  dropout_15 (Dropout)           (None, 75, 80)       0           ['dense_15[0][0]']
#
#  stochastic_depth_15 (Stochasti  (None, 75, 80)      0           ['dropout_15[0][0]']
#  cDepth)
#
#  add_15 (Add)                   (None, 75, 80)       0           ['stochastic_depth_15[0][0]',
#                                                                   'add_14[0][0]']
#
#  layer_normalization_17 (LayerN  (None, 75, 80)      160         ['add_15[0][0]']
#  ormalization)
#
#  conv1d_58 (Conv1D)             (None, 75, 80)       83280       ['layer_normalization_17[0][0]']
#
#  batch_normalization (BatchNorm  (None, 75, 80)      320         ['conv1d_58[0][0]']
#  alization)
#  activation (Activation)        (None, 75, 80)       0           ['batch_normalization[0][0]']
#
#  conv1d_59 (Conv1D)             (None, 75, 80)       83280       ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 75, 80)      320         ['conv1d_59[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 75, 80)       0           ['batch_normalization_1[0][0]']
#
#  add_16 (Add)                   (None, 75, 80)       0           ['activation_1[0][0]',
#                                                                   'layer_normalization_17[0][0]']
#
#  conv1d_60 (Conv1D)             (None, 75, 80)       83280       ['add_16[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 75, 80)      320         ['conv1d_60[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 75, 80)       0           ['batch_normalization_2[0][0]']
#
#  dropout_16 (Dropout)           (None, 75, 80)       0           ['activation_2[0][0]']
#
#  conv1d_61 (Conv1D)             (None, 75, 80)       83280       ['dropout_16[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 75, 80)      320         ['conv1d_61[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 75, 80)       0           ['batch_normalization_3[0][0]']
#
#  conv1d_62 (Conv1D)             (None, 75, 80)       83280       ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 75, 80)      320         ['conv1d_62[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 75, 80)       0           ['batch_normalization_4[0][0]']
#
#  add_17 (Add)                   (None, 75, 80)       0           ['activation_4[0][0]',
#                                                                   'dropout_16[0][0]']
#
#  conv1d_63 (Conv1D)             (None, 75, 80)       83280       ['add_17[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 75, 80)      320         ['conv1d_63[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 75, 80)       0           ['batch_normalization_5[0][0]']
#
#  dropout_17 (Dropout)           (None, 75, 80)       0           ['activation_5[0][0]']
#
#  conv1d_64 (Conv1D)             (None, 75, 80)       83280       ['dropout_17[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 75, 80)      320         ['conv1d_64[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 75, 80)       0           ['batch_normalization_6[0][0]']
#
#  conv1d_65 (Conv1D)             (None, 75, 80)       83280       ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 75, 80)      320         ['conv1d_65[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 75, 80)       0           ['batch_normalization_7[0][0]']
#
#  add_18 (Add)                   (None, 75, 80)       0           ['activation_7[0][0]',
#                                                                   'dropout_17[0][0]']
#
#  conv1d_66 (Conv1D)             (None, 75, 80)       83280       ['add_18[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 75, 80)      320         ['conv1d_66[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 75, 80)       0           ['batch_normalization_8[0][0]']
#
#  dropout_18 (Dropout)           (None, 75, 80)       0           ['activation_8[0][0]']
#
#  flatten (Flatten)              (None, 6000)         0           ['dropout_18[0][0]']
#
#  decoder_features (Reshape)     (None, 6000, 1)      0           ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 1,315,880
# Trainable params: 1,314,440
# Non-trainable params: 1,440
# __________________________________________________________________________________________________
# TensorShape([None, 6000, 1])
